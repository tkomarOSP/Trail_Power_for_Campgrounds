# %%
from pprint import pprint 
from lxml import etree


def pp(e):
    print (etree.tostring(e, pretty_print=True))


# Load and parse the REQIF XML file and the schema file
reqif_file_path = 'TestTemplate.reqif'
schema_file_path = 'reqif_schema.xsd'  # Path to your local schema file


# Parse the schema file
with open(schema_file_path, 'rb') as schema_file:
    schema_doc = etree.parse(schema_file)
schema = etree.XMLSchema(schema_doc)

# Create an XML parser with the schema
parser = etree.XMLParser(schema=schema)

# Parse the REQIF file with schema validation
tree = etree.parse(reqif_file_path, parser)
root = tree.getroot()

# Print the root element
print(f"Root element: {root.tag}")

# Find namespaces in the XML document
namespaces = {k if k else 'default': v for k, v in root.nsmap.items()}
print("namespaces:",namespaces)

# Extract CORE-CONTENT using namespaces if present
core_content = root.find('.//default:CORE-CONTENT', namespaces)
if core_content is not None:
    spec_objects = core_content.findall('.//default:SPEC-OBJECT', namespaces)

    print("Requirements:")
    for spec_object in spec_objects:
        #pprint(spec_object)
        obj_id = spec_object.get('IDENTIFIER', 'N/A')
        #long_name_elem = spec_object.find('.//default:LONG-NAME', namespaces)
        long_name_elem = spec_object.get('LONG-NAME', 'N/A')
        description_elem = spec_object.find('.//default:DESC', namespaces)
        last_change_elem = spec_object.get('LAST-CHANGE', 'N/A')
        #long_name = long_name_elem.text if long_name_elem is not None else 'N/A'
        description = description_elem.text if description_elem is not None else 'N/A'

        print(f"- ID: {obj_id}")
        print(f"  Long Name: {long_name_elem}")
        print(f"  Last Change: {last_change_elem}")
    
        values = spec_object.findall('.//default:VALUES', namespaces)
        for value in values:
            #pp(value)
            htmls = value.findall('.//default:ATTRIBUTE-VALUE-XHTML', namespaces)
            for html in htmls:
                #pp(html)
                html_values = value.findall('.//default:THE-VALUE', namespaces)
                for html_value in html_values:
                    #pp(html_value)
                    div_element = html_value.find('.//ns2:div', namespaces)
                    if div_element is not None:
                        print(f"  HTML Text: {div_element.text}")
                    else:
                        print("  HTML Text element not found.")
                    print()
                    

else:
    print("No CORE-CONTENT found in the REQIF file.")
# Out:
# Root element: {http://www.omg.org/spec/ReqIF/20110401/reqif.xsd}REQ-IF
# namespaces: {'default': 'http://www.omg.org/spec/ReqIF/20110401/reqif.xsd', 'ns2': 'http://www.w3.org/1999/xhtml'}
# Requirements:
# - ID: _2022x_2_c0402fd_1725396723783_216654_17765
#   Long Name: Requirements
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Requirements
#
# - ID: _2022x_2_c0402fd_1725396723792_794076_17799
#   Long Name: Adaptability Requirements
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Adaptability Requirements
#
# - ID: _2022x_2_c0402fd_1725396724395_248106_18091
#   Long Name: Potential Extension
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Potential Extension
#
# - ID: _2022x_2_c0402fd_1725396724394_531136_18090
#   Long Name: Potential Growth
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Potential Growth
#
# - ID: _2022x_2_c0402fd_1725396724394_261433_18089
#   Long Name: Scalability
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Scalability
#
# - ID: _2022x_2_c0402fd_1725396723795_947569_17805
#   Long Name: Cost and Schedule Constraints
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Cost and Schedule Constraints
#
# - ID: _2022x_2_c0402fd_1725396724399_293878_18113
#   Long Name: Cost Constraints
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Cost Constraints
#
# - ID: _2022x_2_c0402fd_1725396724399_893436_18112
#   Long Name: Schedule Constraints
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Schedule Constraints
#
# - ID: _2022x_2_c0402fd_1725396723793_919815_17801
#   Long Name: Design Constraints
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Design Constraints
#
# - ID: _2022x_2_c0402fd_1725396723794_319869_17802
#   Long Name: Environmental Conditions
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Environmental Conditions
#
# - ID: _2022x_2_c0402fd_1725396723789_146078_17793
#   Long Name: Functional Requirements
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Functional Requirements
#
# - ID: _2022x_2_c0402fd_1725396723791_198728_17796
#   Long Name: Interface Requirements
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Interface Requirements
#
# - ID: _2022x_2_c0402fd_1725396724390_85441_18075
#   Long Name: Energy
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Energy
#
# - ID: _2022x_2_c0402fd_1725396724389_435715_18073
#   Long Name: Human Interface
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Human Interface
#
# - ID: _2022x_2_c0402fd_1725396724390_743540_18074
#   Long Name: Information
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Information
#
# - ID: _2022x_2_c0402fd_1725396724391_995767_18076
#   Long Name: Material Exchange
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Material Exchange
#
# - ID: _2022x_2_c0402fd_1725396724389_258811_18072
#   Long Name: Physical Connections
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Physical Connections
#
# - ID: _2022x_2_c0402fd_1725396723794_789456_17803
#   Long Name: Logistical Requirements
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Logistical Requirements
#
# - ID: _2022x_2_c0402fd_1725396724397_853458_18105
#   Long Name: Handling
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Handling
#
# - ID: _2022x_2_c0402fd_1725396724398_158725_18106
#   Long Name: Packaging
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Packaging
#
# - ID: _2022x_2_c0402fd_1725396724397_497413_18104
#   Long Name: Shipping
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Shipping
#
# - ID: _2022x_2_c0402fd_1725396724398_477568_18107
#   Long Name: Sustainment Requirements
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Sustainment Requirements
#
# - ID: _2022x_2_c0402fd_1725396724412_43986_18201
#   Long Name: Level of Support
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Level of Support
#
# - ID: _2022x_2_c0402fd_1725396724412_362101_18202
#   Long Name: Provision of Facilities
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Provision of Facilities
#
# - ID: _2022x_2_c0402fd_1725396724411_817392_18199
#   Long Name: Spare Parts
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Spare Parts
#
# - ID: _2022x_2_c0402fd_1725396724412_948485_18200
#   Long Name: Support Personnel
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Support Personnel
#
# - ID: _2022x_2_c0402fd_1725396724410_331977_18197
#   Long Name: Technical Documentation
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Technical Documentation
#
# - ID: _2022x_2_c0402fd_1725396724411_754302_18198
#   Long Name: Training
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Training
#
# - ID: _2022x_2_c0402fd_1725396724397_628943_18103
#   Long Name: Transportation
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Transportation
#
# - ID: _2022x_2_c0402fd_1725396723792_404438_17798
#   Long Name: Modes and/or States Requirements
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Modes and/or States Requirements
#
# - ID: _2022x_2_c0402fd_1725396723791_95623_17797
#   Long Name: Operational Requirements
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Operational Requirements
#
# - ID: _2022x_2_c0402fd_1725396724393_993848_18082
#   Long Name: Availability
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Availability
#
# - ID: _2022x_2_c0402fd_1725396724393_316050_18083
#   Long Name: Ergonomics
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Ergonomics
#
# - ID: _2022x_2_c0402fd_1725396724393_323280_18084
#   Long Name: Human Factors
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Human Factors
#
# - ID: _2022x_2_c0402fd_1725396724392_969392_18081
#   Long Name: Maintainability
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Maintainability
#
# - ID: _2022x_2_c0402fd_1725396724392_669047_18080
#   Long Name: Reliability
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Reliability
#
# - ID: _2022x_2_c0402fd_1725396724392_185199_18079
#   Long Name: Security
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Security
#
# - ID: _2022x_2_c0402fd_1725396723790_555771_17794
#   Long Name: Performance Requirements
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Performance Requirements
#
# - ID: _2022x_2_c0402fd_1725396723793_794327_17800
#   Long Name: Physical Constraints
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Physical Constraints
#
# - ID: _2022x_2_c0402fd_1725396724395_185964_18094
#   Long Name: Dimensions
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Dimensions
#
# - ID: _2022x_2_c0402fd_1725396724395_184837_18095
#   Long Name: Volume
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Volume
#
# - ID: _2022x_2_c0402fd_1725396724396_995281_18096
#   Long Name: Weight
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Weight
#
# - ID: _2022x_2_c0402fd_1725396723795_287733_17804
#   Long Name: Policies and Regulations
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Policies and Regulations
#
# - ID: _2022x_2_c0402fd_1725396723790_680920_17795
#   Long Name: Usability Requirements
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Usability Requirements
#
# - ID: _2022x_2_c0402fd_1725396724389_231163_18069
#   Long Name: Measurable Effectiveness
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Measurable Effectiveness
#
# - ID: _2022x_2_c0402fd_1725396724388_524752_18068
#   Long Name: Measurable Efficiency
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Measurable Efficiency
#
# - ID: _2022x_2_c0402fd_1725396724388_524857_18067
#   Long Name: Measurable Satisfaction Criteria
#   Last Change: 2024-09-03T14:06:51
#   HTML Text:  Measurable Satisfaction Criteria
